# %% [markdown]
# <a href="https://colab.research.google.com/github/TaichiKogure/CAD2CAE/blob/master/20200626.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://teru-hide.com/cfd-numerical-analysis-square-root2/
# 数値解析

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xn = 2.0    # 初期値
while True:
    print(xn)
    if abs(2-xn**2) < 1.0*10**(-4):    # 判定
        break
    xn = xn/2 + 1/xn
# Out:
# 2.0
# 1.5
# 1.4166666666666665
# 1.4142156862745097

# %% [markdown]
# https://teru-hide.com/cfd-unsteady-diffusion/
# 拡散方程式
